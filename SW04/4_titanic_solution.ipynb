# %% [markdown]
# # IN_SYS - SW03 - Titanic
# ### 02/10/2024 - T. Schwank
#
# ### Goal: Learn how to load data, do some basic exploration, and plot some first graphs
#
# __[seaborn library homepage](https://seaborn.pydata.org/)__

# %% [markdown]
# ## 1. Description of the data
#
# **Preparation:** Download the file 'titanic_data.csv' from ILIAS to your laptop in a folder colled 'data'

# %% [markdown]
# The data set consists of up to 11 data points for each of the Titanic passenger, some passengers have less data points due to some
# missing information:
#
# - **Survived**: Outcome of survival (0 = No; 1 = Yes)
# - **Pclass**: Socio-economic class (1 = Upper class; 2 = Middle class; 3 = Lower class)
# - **Name**: Name of passenger
# - **Sex**: Sex of the passenger
# - **Age**: Age of the passenger
# - **SibSp**: Number of siblings and spouses of the passenger aboard
# - **Parch**: Number of parents and children of the passenger aboard
# - **Ticket**: Ticket number of the passenger
# - **Fare**: Fare paid by the passenger
# - **Cabin** Cabin number of the passenger
# - **Embarked**: Port of embarkation of the passenger (C = Cherbourg; Q = Queenstown; S = Southampton)

# %% [markdown]
# # 2. Load the necessary libraries: pandas, seaborn

# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# # 3. Load the 'titanic_data.csv' file into a Pandas Dataframe called 'titanic_df'
# ### Hint: **no** special options are needed to load the data, just a simple read

# %%
titanic_df = pd.read_csv('data/titanic_data.csv')

# %% [markdown]
# # 4. Print the first 5 rows of the DataFrame 'titanic_df'

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # 5. How many passengers do we have in titanic_df?

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 6. Some insides about the column 'Sex'
#
# ### How many passengers were female, how many male?

# %%
titanic_df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# # 6.1 Create a 'countplot' visualizing how many females and males
#
# ### **Hint**: you can find details how to create a countplot with seaborn library here:
# ### __[seaborn countplot](https://seaborn.pydata.org/generated/seaborn.countplot.html)__

# %%
sns.countplot(x='Sex', data=titanic_df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>
