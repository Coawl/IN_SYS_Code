# %% [markdown]
# # IN_SYS - SW04 - Introduction to visualizations
# ### 09/10/2024 - S. Lazarevic
#
# Goal: Understand how to visualize data with seaborn and matplotlib
#
# __[seaborn library homepage](https://seaborn.pydata.org/)__

# %% [markdown]
# # 1. Import the required libraries

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 2. Read the sample data from FIFA dataset
#
# The data contains historical FIFA rankings for six countries: Argentina (ARG), Brazil (BRA), Spain (ESP), France (FRA), Germany (GER), and Italy (ITA)
#
# Name of the data file, please download from ILIAS:  **fifa.csv**
#
# When reading from the file, use Date as the index column, as our plot will take it as x-axis.
# Also, when reading from the file, parse the dates so that matplotlib can aggregate the dates into years on the x-axis.

# %% [markdown]
# ## 2.1 Show the first 5 rows

# %% [markdown]
# # 3. Plot the data

# %%
# Line chart showing how FIFA rankings evolved over time

# %% [markdown]
# We see that the best-ranked teams are shown at the bottom of the graph, and the visualization is too compressed.
# Change the plot size, flip the y axis and plot again.

# %%
# Set the width and height of the figure (14 "inches" wide, 6 "inches" tall)
