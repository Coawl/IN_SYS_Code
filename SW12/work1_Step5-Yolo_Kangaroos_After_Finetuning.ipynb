# %% [markdown]
# # Intelligent Systems | HS2025 | SW12
# Homework - Fine-Tuning a YOLO11 model with images from Kangaroos
#
# ## Step 5 - Check fine-tuned model
#
# **Note:** Some lines of the code below needs your help. I replaced some parts with "XXXXXX". Try to figure out what needs to be changed. You have to make two  changes.
#
# **Hint**: Just check the Jupyter Notebook concerning the Racoon example from the lecture. You wil find all answers in those Notebooks.

# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO
import os
import numpy as np
from pathlib import Path
import requests

# %%
# Get the current folder
current_folder = Path().resolve()

# Combine the folder path with the yolo file name
file_name = 'yolo_kangaroo_finetuned.pt'
file_path = current_folder / file_name

print(f"The full path to the file is: {file_path}")
# Load the YOLOv11 model
model = XXXXXXXXXXXXXXXXXXXXXXXX
# Out:
# The full path to the file is: C:\Users\ts\IN_SYS\in_sys\SW12\HomeworkAssignment\yolo_kangaroo_finetuned.pt

# %%
# Sample raccoon images
sample_images = [
    "kangaroo/images/00001.jpg",
    "kangaroo/images/00002.jpg",
    "kangaroo/images/00003.jpg",
    "kangaroo/images/00004.jpg",
    "kangaroo/images/00005.jpg",
]

# %%
# Function to display images with predictions
def display_image_with_predictions(img_path, predictions):
    img = cv2.imread(img_path)
    for box in predictions[0].boxes:  # Iterate over detected boxes
        x1, y1, x2, y2 = map(int, box.xyxy[0])  # Bounding box coordinates
        conf = float(box.conf[0])  # Confidence score
        cls = int(box.cls[0])  # Class index
        label = f"{model.names[cls]} {conf:.2f}"  # Class name and confidence

        # Draw bounding box
        cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)

        # Draw label
        cv2.putText(
            img, label, (x1, y1 - 10),
            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2
        )

    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()

# Run inference on each sample image
for img_path in sample_images:
    # img_full_path = os.path.join("kangaroo/images", img_path)
    results = XXXXXXXXXXXXXXXXXXX  # Run YOLO inference
    display_image_with_predictions(img_path, results)
# Out:
# image 1/1 C:\Users\ts\IN_SYS\in_sys\SW12\HomeworkAssignment\kangaroo\images\00001.jpg: 480x640 2 kangaroos, 228.4ms
# Speed: 6.0ms preprocess, 228.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# image 1/1 C:\Users\ts\IN_SYS\in_sys\SW12\HomeworkAssignment\kangaroo\images\00002.jpg: 384x640 2 kangaroos, 171.0ms
# Speed: 3.1ms preprocess, 171.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# image 1/1 C:\Users\ts\IN_SYS\in_sys\SW12\HomeworkAssignment\kangaroo\images\00003.jpg: 416x640 1 kangaroo, 280.9ms
# Speed: 9.0ms preprocess, 280.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# image 1/1 C:\Users\ts\IN_SYS\in_sys\SW12\HomeworkAssignment\kangaroo\images\00004.jpg: 480x640 2 kangaroos, 307.8ms
# Speed: 3.0ms preprocess, 307.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# image 1/1 C:\Users\ts\IN_SYS\in_sys\SW12\HomeworkAssignment\kangaroo\images\00005.jpg: 416x640 1 kangaroo, 126.8ms
# ...
