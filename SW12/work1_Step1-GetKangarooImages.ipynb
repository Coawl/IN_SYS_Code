# %% [markdown]
# # Intelligent Systems | HS2025 | SW12
# Homework - Fine-Tuning a YOLO11 model with images from Kangaroos
#
# ## Step 1 - Download the images from Github
#
# Just run the Notebook to download the images and annotaions (the bounding boxes). When done, you should see a new folder called "kangoroo".
#
# ![Kangaroo](data:image/jpeg;base64,...)

# %%
# Clone the Kangaroo dataset repository (if not already downloaded)
import os

if not os.path.exists("kangaroo"):
    os.system("git clone https://github.com/experiencor/kangaroo.git")
